# %%
yield_df = pd.read_csv("../data/raw/Yield_curve_history.csv")

print(yield_df.shape)
print(yield_df.head())
print(yield_df.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 yield_df = pd.read_csv("../data/raw/Yield_curve_history.csv")
#       2
#       3 print(yield_df.shape)
#       4 print(yield_df.head())
#
# NameError: name 'pd' is not defined
